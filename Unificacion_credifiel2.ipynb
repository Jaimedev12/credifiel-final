# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# Importing the necessary libraries
import time

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the dataset
df = pd.read_csv("/content/gdrive/MyDrive/df_new.csv").copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2114172 entries, 0 to 2114171
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   idListaCobro        int64
#  1   idCredito           int64
#  2   consecutivoCobro    int64
#  3   idBanco_x           int64
#  4   montoExigible       float64
#  5   montoCobrar         float64
#  6   montoCobrado        float64
#  7   fechaCobroBanco     object
#  8   idRespuestaBanco    float64
#  9   caso_exitoso        int64
#  10  fechaCreacionLista  object
#  11  idBanco_y           int64
#  12  fechaEnvioCobro     object
#  13  idEmisora           int64
#  14  id_estrategia       int64
#  15  banco               int64
#  16  servicio            object
#  17  tiempo_feedback     int64
#  18  Hora_ inicio        object
#  19  Hora_fin            object
# dtypes: float64(4), int64(10), object(6)
# memory usage: 322.6+ MB

# %%
df
# Out:
#          idListaCobro  idCredito  consecutivoCobro  idBanco_x  montoExigible  \
# 0              155938     738973          41396434          2         622.87
# 1              155938     739017          41396435          2        1069.11
# 2              155939     739185          41396436          2        4340.83
# 3              155940     732324          41396437          2        2134.21
# 4              155940     737028          41396438          2         815.76
# ...               ...        ...               ...        ...            ...
# 2114167        162271     741795          44299050          2         980.32
# 2114168        162271     741795          44299051          2        1633.86
# 2114169        162271     742470          44299052          2         810.44
# 2114170        162271     742470          44299053          2        1350.74
# 2114171        162271     742470          44299054          2         540.30
#
# ...

# %%
iguales = (df['idBanco_y'] == df['banco']).all()
print("¿Todas las filas son iguales entre idBanco_x e idBanco_y?", iguales)
# Out:
# ¿Todas las filas son iguales entre idBanco_x e idBanco_y? True

# %%
df.drop(columns=['banco'], inplace=True)

# %% [markdown]
# quiero cambiar en mi columna servicio los strings por estos valores1	TRADICIONAL
# 2	INTERBANCA
# 3	PARCIAL
# 4	MATUTINO
# 5	EN LINEA
# 6	REINTENTO

# %%
# Diccionario de mapeo
mapa_servicio = {
    "TRADICIONAL": 1,
    "INTERBANCA": 2,
    "PARCIAL": 3,
    "MATUTINO": 4,
    "EN LINEA": 5,
    "REINTENTO": 6
}

# Aplicar el mapeo
df['servicio'] = df['servicio'].map(mapa_servicio)

# %%
df
# Out:
#          idListaCobro  idCredito  consecutivoCobro  idBanco_x  montoExigible  \
# 0              155938     738973          41396434          2         622.87
# 1              155938     739017          41396435          2        1069.11
# 2              155939     739185          41396436          2        4340.83
# 3              155940     732324          41396437          2        2134.21
# 4              155940     737028          41396438          2         815.76
# ...               ...        ...               ...        ...            ...
# 2114167        162271     741795          44299050          2         980.32
# 2114168        162271     741795          44299051          2        1633.86
# 2114169        162271     742470          44299052          2         810.44
# 2114170        162271     742470          44299053          2        1350.74
# 2114171        162271     742470          44299054          2         540.30
#
# ...

# %%
df2=pd.read_excel("Libro3.xlsx")
df2
# Out:
#     id_estrategia  CobroExito  CobroDevuelta
# 0               1        8.00           8.00
# 1               2        6.00           6.00
# 2               3        1.60           1.60
# 3               4        8.00           8.00
# 4               5        4.00           4.00
# 5               6        2.50           2.50
# 6               7        2.50           2.50
# 7               8        4.50           4.50
# 8               9        1.75           1.75
# 9              10        1.75           1.75
# 10             11        2.82           2.37
# 11             12        3.18           2.58
# 12             13        2.82           2.37
# 13             14        1.97           1.42

# %%
# Hacemos el merge con df usando la columna 'idListaCobro'
df = df.merge(df2, on='id_estrategia', how='left')

# %%
df
# Out:
#          idListaCobro  idCredito  consecutivoCobro  idBanco_x  montoExigible  \
# 0              155938     738973          41396434          2         622.87
# 1              155938     739017          41396435          2        1069.11
# 2              155939     739185          41396436          2        4340.83
# 3              155940     732324          41396437          2        2134.21
# 4              155940     737028          41396438          2         815.76
# ...               ...        ...               ...        ...            ...
# 2114167        162271     741795          44299050          2         980.32
# 2114168        162271     741795          44299051          2        1633.86
# 2114169        162271     742470          44299052          2         810.44
# 2114170        162271     742470          44299053          2        1350.74
# 2114171        162271     742470          44299054          2         540.30
#
# ...

# %%
df6=pd.read_csv("Capital.csv")
df6
# Out:
#        idCredito     pagare   capital fechaAperturaCredito  Unnamed: 4
# 0          10456  120379.68  50000.00           26/05/2008         NaN
# 1          10439  122306.40  50800.00           03/06/2008         NaN
# 2          10297  132333.12  46000.00           09/06/2008         NaN
# 3          10327   77535.84  40000.00           13/06/2008         NaN
# 4          10073   96304.32  40000.00           30/06/2008         NaN
# ...          ...        ...       ...                  ...         ...
# 97223     570762    6896.82   6353.51           06/10/2020         NaN
# 97224     570763    5517.45   5083.50           06/10/2020         NaN
# 97225     570842    7143.15   6557.10           06/10/2020         NaN
# 97226     570867    7250.96   6798.79           06/10/2020         NaN
# 97227     572233   13983.80  13111.93           23/10/2020         NaN
#
# [97228 rows x 5 columns]

# %%
df6.isna().sum()
# Out:
# idCredito                   0
# pagare                      0
# capital                     0
# fechaAperturaCredito        0
# Unnamed: 4              97228
# dtype: int64

# %%
# Hacemos el merge con df usando la columna 'idListaCobro'
df = df.merge(df6, on='idCredito', how='left')

# %%
df.drop(columns=['Unnamed: 4'], inplace=True)

# %%
df.isna().sum()
# Out:
# idListaCobro                  0
# idCredito                     0
# consecutivoCobro              0
# idBanco_x                     0
# montoExigible                 0
# montoCobrar                   0
# montoCobrado                  0
# fechaCobroBanco         2025884
# idRespuestaBanco              0
# caso_exitoso                  0
# fechaCreacionLista            0
# idBanco_y                     0
# fechaEnvioCobro               0
# idEmisora                     0
# id_estrategia                 0
# servicio                      0
# tiempo_feedback               0
# Hora_ inicio                  0
# Hora_fin                      0
# CobroExito                    0
# CobroDevuelta                 0
# pagare                       30
# capital                      30
# fechaAperturaCredito         30
# dtype: int64

# %%
df_pagare_na = df[df['pagare'].isna()]
print(df_pagare_na)
# Out:
#          idListaCobro  idCredito  consecutivoCobro  idBanco_x  montoExigible  \
# 123784         156485     723964          41574340         21       32268.46
# 123785         156485     723964          41574341         21       32268.46
# 123786         156485     723964          41574342         21       32268.46
# 373579         157137     723964          41884853         21       32268.46
# 373580         157137     723964          41884854         21       32268.46
# 373581         157137     723964          41884855         21       32268.46
# 670671         157791     723964          42257608         21       32268.46
# 670672         157791     723964          42257609         21       32268.46
# 670673         157791     723964          42257610         21       32268.46
# 963575         158593     723964          42676703         21       32268.46
# 963576         158593     723964          42676704         21       32268.46
# ...

# %%
df = df[~df['pagare'].isna()]

# %%
df.isna().sum()
# Out:
# idListaCobro                  0
# idCredito                     0
# consecutivoCobro              0
# idBanco_x                     0
# montoExigible                 0
# montoCobrar                   0
# montoCobrado                  0
# fechaCobroBanco         2025881
# idRespuestaBanco              0
# caso_exitoso                  0
# fechaCreacionLista            0
# idBanco_y                     0
# fechaEnvioCobro               0
# idEmisora                     0
# id_estrategia                 0
# servicio                      0
# tiempo_feedback               0
# Hora_ inicio                  0
# Hora_fin                      0
# CobroExito                    0
# CobroDevuelta                 0
# pagare                        0
# capital                       0
# fechaAperturaCredito          0
# dtype: int64

# %%
df.to_csv("df_n2.csv", index=False, encoding='utf-8-sig')
